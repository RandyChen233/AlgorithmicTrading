# %%
import datetime as dt
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
tickers= ['600600.SS','600132.SS']

# %%
start = dt.datetime.today()-dt.timedelta(365)
end = dt.datetime.today()
cl_price = pd.DataFrame()

# %%
for ticker in tickers:
    cl_price[ticker] = yf.download(ticker,start,end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
cl_price.dropna(axis=0,how='any',inplace=True)

# %%
daily_return = cl_price.pct_change()

# %%
plt.figure(dpi=300);
cl_price.plot();
plt.legend({'Tsingdao Brewery Co.,ltd','Chongqing Brewery Co.,ltd'},fontsize=11,loc='upper right');
plt.ylabel('Closing price')
# Out:
# Text(0, 0.5, 'Closing price')

# %%
plt.figure(dpi=300);
cl_price.plot(subplots=True,layout=(2,1),sharex=True,grid=True);

# %%
daily_return
# Out:
#             600600.SS  600132.SS
# Date
# 2020-12-28        NaN        NaN
# 2020-12-29   0.010398  -0.000347
# 2020-12-30   0.005448   0.017424
# 2020-12-31  -0.002609   0.013802
# 2021-01-04   0.030986   0.013446
# ...               ...        ...
# 2021-12-20  -0.006519  -0.023825
# 2021-12-21   0.032509   0.024274
# 2021-12-22  -0.002151   0.024023
# 2021-12-23  -0.005977  -0.007989
# 2021-12-24   0.035982   0.003835
#
# [242 rows x 2 columns]

# %%
daily_return.plot(subplots=True,layout=(2,1));
# Out:
# array([[<AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>]], dtype=object)

# %%
(1+daily_return).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-notebook')

# %%
fig,ax = plt.subplots(dpi=400);
ax.set(title='Mean Daily Return of Stocks',xlabel='Stocks',ylabel='Mean Return');
plt.bar(x=daily_return.columns,height=daily_return.mean(),color=['red','green']);
